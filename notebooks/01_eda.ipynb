# %% [markdown]
# # 🏆 EDA for Dashboarding - Global Energy Consumption Project
#
# 🔍 **Objective:**
# This exploratory analysis aims to understand the data distribution of the global energy dataset from the Our World in Data platform and extract key insights for developing a dashboard using Dash.
#
# 📊 **Data Source:** [`owid-energy-data.csv`]

# %% [markdown]
# ## 1️⃣ 📂 Data Loading and Initial Setup

# %%
# 📚 Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import missingno as msno  # Uncomment to quickly visualize missing values

# 📂 Load dataset
df = pd.read_csv('../data/owid-energy-data.csv')

# 🔍 Display first rows
df.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# 0                      NaN  ...               0.0                 NaN
# 1                      NaN  ...               0.0                 NaN
# 2                      NaN  ...               0.0                 NaN
# 3                      NaN  ...               0.0                 NaN
# 4                      NaN  ...               0.0                 NaN
#
#    wind_cons_change_pct  wind_cons_change_twh  wind_consumption  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
#
#    wind_elec_per_capita  wind_electricity  wind_energy_per_capita  \
# 0                   NaN               0.0                     NaN
# 1                   NaN               0.0                     NaN
# 2                   NaN               0.0                     NaN
# 3                   NaN               0.0                     NaN
# 4                   NaN               0.0                     NaN
#
#    wind_share_elec  wind_share_energy
# 0              0.0                NaN
# 1              0.0                NaN
# 2              0.0                NaN
# 3              0.0                NaN
# 4              0.0                NaN
#
# [5 rows x 130 columns]

# %%
# Dataset Overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16936 entries, 24 to 21811
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  16936 non-null  object
#  1   year                                     16936 non-null  int64
#  2   iso_code                                 16812 non-null  object
#  3   population                               16806 non-null  float64
#  4   gdp                                      11572 non-null  float64
#  5   biofuel_electricity                      5293 non-null   float64
#  6   carbon_intensity_elec                    5294 non-null   float64
#  7   coal_electricity                         5667 non-null   float64
#  8   coal_production                          13120 non-null  float64
#  9   coal_share_elec                          5644 non-null   float64
#  10  electricity_demand                       5322 non-null   float64
#  11  electricity_generation                   6213 non-null   float64
#  12  energy_cons_change_pct                   9678 non-null   float64
#  13  energy_cons_change_twh                   9830 non-null   float64
#  14  energy_per_gdp                           7737 non-null   float64
#  15  fossil_electricity                       5716 non-null   float64
#  16  fossil_energy_per_capita                 3688 non-null   float64
#  17  fossil_fuel_consumption                  3688 non-null   float64
#  18  gas_electricity                          5601 non-null   float64
#  19  gas_production                           13305 non-null  float64
#  20  gas_share_elec                           5578 non-null   float64
#  21  greenhouse_gas_emissions                 5322 non-null   float64
#  22  hydro_electricity                        7394 non-null   float64
#  23  low_carbon_electricity                   6593 non-null   float64
#  24  net_elec_imports                         5298 non-null   float64
#  25  net_elec_imports_share_demand            5270 non-null   float64
#  26  nuclear_electricity                      8110 non-null   float64
#  27  nuclear_share_elec                       6082 non-null   float64
#  28  oil_electricity                          5711 non-null   float64
#  29  oil_production                           13783 non-null  float64
#  30  oil_share_elec                           5688 non-null   float64
#  31  other_renewable_electricity              6841 non-null   float64
#  32  other_renewable_exc_biofuel_electricity  4729 non-null   float64
#  33  per_capita_electricity                   6213 non-null   float64
#  34  primary_energy_consumption               10049 non-null  float64
#  35  renewables_consumption                   4198 non-null   float64
#  36  renewables_electricity                   6593 non-null   float64
#  37  renewables_share_elec                    5974 non-null   float64
#  38  solar_electricity                        6642 non-null   float64
#  39  wind_electricity                         6671 non-null   float64
# dtypes: float64(37), int64(1), object(2)
# memory usage: 5.3+ MB

# %% [markdown]
# ## 2️⃣ 🔍 Análisis de la Estructura del Dataset

# %%
# 🏷️ Data Types
df.dtypes
# Out:
# country                                     object
# year                                         int64
# iso_code                                    object
# population                                 float64
# gdp                                        float64
# biofuel_electricity                        float64
# carbon_intensity_elec                      float64
# coal_electricity                           float64
# coal_production                            float64
# coal_share_elec                            float64
# electricity_demand                         float64
# electricity_generation                     float64
# energy_cons_change_pct                     float64
# energy_cons_change_twh                     float64
# energy_per_gdp                             float64
# fossil_electricity                         float64
# fossil_energy_per_capita                   float64
# fossil_fuel_consumption                    float64
# gas_electricity                            float64
# gas_production                             float64
# gas_share_elec                             float64
# greenhouse_gas_emissions                   float64
# hydro_electricity                          float64
# low_carbon_electricity                     float64
# net_elec_imports                           float64
# net_elec_imports_share_demand              float64
# nuclear_electricity                        float64
# nuclear_share_elec                         float64
# oil_electricity                            float64
# oil_production                             float64
# oil_share_elec                             float64
# other_renewable_electricity                float64
# other_renewable_exc_biofuel_electricity    float64
# per_capita_electricity                     float64
# primary_energy_consumption                 float64
# renewables_consumption                     float64
# renewables_electricity                     float64
# renewables_share_elec                      float64
# solar_electricity                          float64
# wind_electricity                           float64
# dtype: object

# %%
# 🔢 Data Type Count
df.dtypes.value_counts()
# Out:
# float64    127
# object       2
# int64        1
# Name: count, dtype: int64

# %%
df = df[
['country',
'year',
'iso_code',
'population',
'gdp',
'biofuel_electricity',
'carbon_intensity_elec',
'coal_electricity',
'coal_production',
'coal_share_elec',
'electricity_demand',
'electricity_generation',
'energy_cons_change_pct',
'energy_cons_change_twh',
'energy_per_gdp',
'fossil_electricity',
'fossil_energy_per_capita',
'fossil_fuel_consumption',
'gas_electricity',
'gas_production',
'gas_share_elec',
'greenhouse_gas_emissions',
'hydro_electricity',
'low_carbon_electricity',
'net_elec_imports',
'net_elec_imports_share_demand',
'nuclear_electricity',
'nuclear_share_elec',
'oil_electricity',
'oil_production',
'oil_share_elec',
'other_renewable_electricity',
'other_renewable_exc_biofuel_electricity',
'per_capita_electricity',
'primary_energy_consumption',
'renewables_consumption',
'renewables_electricity',
'renewables_share_elec',
'solar_electricity',
'wind_electricity']
]

# %%
# 📊 Updated Dataset Overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21812 entries, 0 to 21811
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  21812 non-null  object
#  1   year                                     21812 non-null  int64
#  2   iso_code                                 16812 non-null  object
#  3   population                               18447 non-null  float64
#  4   gdp                                      11775 non-null  float64
#  5   biofuel_electricity                      5834 non-null   float64
#  6   carbon_intensity_elec                    5835 non-null   float64
#  7   coal_electricity                         6709 non-null   float64
#  8   coal_production                          16548 non-null  float64
#  9   coal_share_elec                          6686 non-null   float64
#  10  electricity_demand                       5863 non-null   float64
#  11  electricity_generation                   7411 non-null   float64
#  12  energy_cons_change_pct                   11720 non-null  float64
#  13  energy_cons_change_twh                   11913 non-null  float64
#  14  energy_per_gdp                           7789 non-null   float64
#  15  fossil_electricity                       6728 non-null   float64
#  16  fossil_energy_per_capita                 4298 non-null   float64
#  17  fossil_fuel_consumption                  5058 non-null   float64
#  18  gas_electricity                          6613 non-null   float64
#  19  gas_production                           16839 non-null  float64
#  20  gas_share_elec                           6590 non-null   float64
#  21  greenhouse_gas_emissions                 5863 non-null   float64
#  22  hydro_electricity                        9037 non-null   float64
#  23  low_carbon_electricity                   7997 non-null   float64
#  24  net_elec_imports                         5575 non-null   float64
#  25  net_elec_imports_share_demand            5547 non-null   float64
#  26  nuclear_electricity                      9681 non-null   float64
#  27  nuclear_share_elec                       7202 non-null   float64
#  28  oil_electricity                          6648 non-null   float64
#  29  oil_production                           17480 non-null  float64
#  30  oil_share_elec                           6625 non-null   float64
#  31  other_renewable_electricity              8425 non-null   float64
#  32  other_renewable_exc_biofuel_electricity  5270 non-null   float64
#  33  per_capita_electricity                   6640 non-null   float64
#  34  primary_energy_consumption               12178 non-null  float64
#  35  renewables_consumption                   5575 non-null   float64
#  36  renewables_electricity                   8109 non-null   float64
#  37  renewables_share_elec                    7152 non-null   float64
#  38  solar_electricity                        8202 non-null   float64
#  39  wind_electricity                         8234 non-null   float64
# dtypes: float64(37), int64(1), object(2)
# memory usage: 6.7+ MB

# %% [markdown]
# ## 3️⃣ 📊 Exploración de Datos Numéricos y Categóricos

# %%
# df description
df.describe()
# Out:
#                year    population           gdp  biofuel_electricity  \
# count  21812.000000  1.844700e+04  1.177500e+04          5834.000000
# mean    1974.195718  1.054051e+08  4.260596e+11            11.262839
# std       35.342860  4.665375e+08  3.508591e+12            49.585627
# min     1900.000000  1.833000e+03  1.642060e+08             0.000000
# 25%     1946.000000  1.714291e+06  1.438637e+10             0.000000
# 50%     1984.000000  6.998022e+06  4.393385e+10             0.010000
# 75%     2004.000000  2.571993e+07  1.830838e+11             0.720000
# max     2023.000000  8.045311e+09  1.301126e+14           678.740000
#
#        carbon_intensity_elec  coal_electricity  coal_production  \
# count            5835.000000       6709.000000     16548.000000
# mean              480.690530        325.273938       984.531283
# std               240.856982       1138.943544      3541.538677
# min                 0.000000          0.000000         0.000000
# 25%               302.920500          0.000000         0.000000
# 50%               525.184000          0.250000         1.351000
# 75%               652.174000         35.540000       114.864750
# max              1306.723000      10467.930000     49789.156000
#
#        coal_share_elec  electricity_demand  electricity_generation  ...  \
# count      6686.000000         5863.000000             7411.000000  ...
# mean         17.278316          612.426238              780.497711  ...
# std          24.184234         2479.537207             2594.874681  ...
# min           0.000000            0.000000                0.000000  ...
# 25%           0.000000            1.465000                2.250000  ...
# 50%           1.785000           11.680000               21.720000  ...
# 75%          32.464500           88.725000              151.605000  ...
# max         100.000000        29479.051000            29479.051000  ...
#
#        oil_share_elec  other_renewable_electricity  \
# count     6625.000000                  8425.000000
# mean        29.463696                    13.564510
# std         36.444605                    52.878824
# min          0.000000                     0.000000
# 25%          2.117000                     0.000000
# 50%          8.981000                     0.056000
# 75%         50.536000                     1.992000
# max        100.000000                   768.550000
#
#        other_renewable_exc_biofuel_electricity  per_capita_electricity  \
# count                              5270.000000             6640.000000
# mean                                  2.026583             4035.874906
# std                                   7.461600             5060.466488
# min                                   0.000000                0.000000
# 25%                                   0.000000              654.331500
# 50%                                   0.000000             2544.710500
# 75%                                   0.000000             5742.243250
# max                                  89.810000            56030.785000
#
#        primary_energy_consumption  renewables_consumption  \
# count                12178.000000             5575.000000
# mean                  4361.508233              589.288174
# std                  15196.647085             1665.876212
# min                      0.000000                0.000000
# 25%                      8.028500                7.765000
# 50%                     85.812000               46.549000
# 75%                    776.378500              265.062500
# max                 172119.062000            25064.225000
#
#        renewables_electricity  renewables_share_elec  solar_electricity  \
# count             8109.000000            7152.000000        8202.000000
# mean               171.916037              29.661346           8.197346
# std                571.256380              30.555233          61.282171
# min                  0.000000               0.000000           0.000000
# 25%                  0.210000               3.333000           0.000000
# 50%                  4.885000              18.332500           0.000000
# 75%                 40.201000              50.000000           0.030000
# max               8913.900000             100.000000        1629.900000
#
#        wind_electricity
# count       8234.000000
# mean          18.936078
# std          110.680131
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.150000
# max         2304.440000
#
# [8 rows x 38 columns]

# %%
# 📋 List of Categorical Columns
df.select_dtypes(include='object').nunique()
# Out:
# country     221
# iso_code    220
# dtype: int64

# %%
# 📊 Distribution of Values in Key Categorical Variables
categorical_columns = ["country", "year"]

for col in categorical_columns:
    print(f"Value distribution for {col}:")
    print(df[col].value_counts().head(10))
    print("\n")
# Out:
# Distribución de valores para country:
# country
# Zimbabwe                124
# Zambia                  124
# Africa                  124
# United Kingdom          124
# United States           124
# United Arab Emirates    124
# Turkey                  124
# Portugal                124
# Tunisia                 124
# Trinidad and Tobago     124
# Name: count, dtype: int64
#
#
# Distribución de valores para year:
# year
# 2003    288
# 2004    288
# 2005    288
# 2012    288
# 2015    288
# 2014    288
# 2013    288
# 2016    288
# 2002    287
# 2001    287
# Name: count, dtype: int64

# %% [markdown]
# ## 4️⃣ 🛠 Limpieza de Datos y Manejo de Valores Nulos

# %%
# 🌍 Filter rows: Keep non-null iso_code and "World" entries
df = df[df['iso_code'].notnull() | (df['country'] == 'World')]

# %%
# 📏 DataFrame Shape
df.shape
# Out:
# (16936, 130)

# %%
# 🌍 Country Occurrence Counter
df.groupby('country')['country'].value_counts()
# Out:
# country
# Afghanistan       123
# Albania           123
# Algeria           124
# American Samoa     43
# Angola            124
#                  ...
# Western Sahara     42
# World             124
# Yemen              44
# Zambia            124
# Zimbabwe          124
# Name: count, Length: 221, dtype: int64

# %%
# 🌍 List of Unique Countries
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Angola',
#        'Antarctica', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor',
#        'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Falkland Islands',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Lithuania', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Martinique', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Mongolia', 'Montenegro',
#        'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
#        'Nauru', 'Nepal', 'Netherlands', 'Netherlands Antilles',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North Korea', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan',
#        'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Reunion', 'Romania', 'Russia', 'Rwanda', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'United States Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela', 'Vietnam', 'Western Sahara', 'World', 'Yemen',
#        'Zambia', 'Zimbabwe'], dtype=object)

# %% [markdown]
# ## Dataset Preprocessing

# %% [markdown]
# ## 1. Understanding Context and Objectives
#
# #### Key Questions:
# - How has the energy mix (renewable vs. fossil) evolved by country/region?
# - Is there a correlation between GDP, population, and energy consumption?
# - Which countries are leading the transition to clean energy?
# - How does carbon intensity relate to economic growth?

# %% [markdown]
# ### 2. Assessing Data Quality
# #### Initial Steps:
# - **Missing values**: Identify columns with missing data (e.g., `carbon_intensity_elec`, `coal_share_elec`).
#   - Are they random or systematic? (e.g., countries with no biofuel data).

# %%
# 📉 List of Null Values per Column
df.isna().sum()
# Out:
# country                                        0
# year                                           0
# iso_code                                     124
# population                                   130
# gdp                                         5364
# biofuel_electricity                        11643
# carbon_intensity_elec                      11642
# coal_electricity                           11269
# coal_production                             3816
# coal_share_elec                            11292
# electricity_demand                         11614
# electricity_generation                     10723
# energy_cons_change_pct                      7258
# energy_cons_change_twh                      7106
# energy_per_gdp                              9199
# fossil_electricity                         11220
# fossil_energy_per_capita                   13248
# fossil_fuel_consumption                    13248
# gas_electricity                            11335
# gas_production                              3631
# gas_share_elec                             11358
# greenhouse_gas_emissions                   11614
# hydro_electricity                           9542
# low_carbon_electricity                     10343
# net_elec_imports                           11638
# net_elec_imports_share_demand              11666
# nuclear_electricity                         8826
# nuclear_share_elec                         10854
# oil_electricity                            11225
# oil_production                              3153
# oil_share_elec                             11248
# other_renewable_electricity                10095
# other_renewable_exc_biofuel_electricity    12207
# per_capita_electricity                     10723
# primary_energy_consumption                  6887
# renewables_consumption                     12738
# renewables_electricity                     10343
# renewables_share_elec                      10962
# solar_electricity                          10294
# wind_electricity                           10265
# dtype: int64

# %% [markdown]
#  ⏳ Temporal Consistency: Do all countries have data for the same year range?
#  If not, this may impact comparative analyses.

# %%
# 📆 Available Years per Country
df.groupby('country')['year'].sum()
# Out:
# country
# Afghanistan       241203
# Albania           241203
# Algeria           243226
# American Samoa     86043
# Angola            243226
#                    ...
# Western Sahara     84021
# World             243226
# Yemen              88066
# Zambia            243226
# Zimbabwe          243226
# Name: year, Length: 221, dtype: int64

# %% [markdown]
# #### 🚨 Outliers: Identify anomalous values
# (e.g., negative coal production, unrealistic population jumps).

# %%
df.describe()
# Out:
#                year    population           gdp  biofuel_electricity  \
# count  16936.000000  1.680600e+04  1.157200e+04          5293.000000
# mean    1974.083137  5.520719e+07  4.237817e+11             3.491721
# std       35.564210  3.832054e+08  3.537319e+12            29.273391
# min     1900.000000  1.833000e+03  1.642060e+08             0.000000
# 25%     1945.000000  1.300349e+06  1.406521e+10             0.000000
# 50%     1984.000000  5.787424e+06  4.260187e+10             0.000000
# 75%     2004.000000  1.788399e+07  1.778932e+11             0.290000
# max     2023.000000  8.045311e+09  1.301126e+14           678.740000
#
#        carbon_intensity_elec  coal_electricity  coal_production  \
# count            5294.000000       5667.000000     13120.000000
# mean              476.450889         96.189726       347.607286
# std               246.893981        669.464332      2403.353737
# min                 0.000000          0.000000         0.000000
# 25%               285.714000          0.000000         0.000000
# 50%               523.971500          0.000000         0.000000
# 75%               653.846000          7.890000        13.951750
# max              1306.723000      10467.930000     49789.156000
#
#        coal_share_elec  electricity_demand  electricity_generation  ...  \
# count      5644.000000         5322.000000             6213.000000  ...
# mean         14.279053          204.936577              229.665867  ...
# std          23.744970         1576.780337             1589.163521  ...
# min           0.000000            0.000000                0.000000  ...
# 25%           0.000000            1.030000                1.300000  ...
# 50%           0.000000            8.915000               12.890000  ...
# 75%          21.399000           52.447500               59.820000  ...
# max         100.000000        29479.051000            29479.051000  ...
#
#        oil_share_elec  other_renewable_electricity  \
# count     5688.000000                  6841.000000
# mean        32.876218                     3.915001
# std         38.105938                    30.490607
# min          0.000000                     0.000000
# 25%          1.820750                     0.000000
# 50%         10.997500                     0.010000
# 75%         64.397750                     0.473000
# max        100.000000                   768.550000
#
#        other_renewable_exc_biofuel_electricity  per_capita_electricity  \
# count                              4729.000000             6213.000000
# mean                                  0.663303             4020.348434
# std                                   5.055308             5160.315008
# min                                   0.000000                0.000000
# 25%                                   0.000000              636.654000
# 50%                                   0.000000             2495.600000
# 75%                                   0.000000             5565.689000
# max                                  89.810000            56030.785000
#
#        primary_energy_consumption  renewables_consumption  \
# count                10049.000000             4198.000000
# mean                  1206.628474              248.846076
# std                   8821.367093             1313.770673
# min                      0.000000                0.000000
# 25%                      5.079000                4.163750
# 50%                     47.725000               22.179000
# 75%                    298.780000               93.500000
# max                 172119.062000            25064.225000
#
#        renewables_electricity  renewables_share_elec  solar_electricity  \
# count             6593.000000            5974.000000        6642.000000
# mean                52.238649              29.642720           2.335147
# std                364.750546              31.925069          36.010189
# min                  0.000000               0.000000           0.000000
# 25%                  0.070000               1.615250           0.000000
# 50%                  1.950000              16.900500           0.000000
# 75%                 12.630000              52.021750           0.010000
# max               8913.900000             100.000000        1629.900000
#
#        wind_electricity
# count       6671.000000
# mean           5.210859
# std           64.424423
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.020000
# max         2304.440000
#
# [8 rows x 38 columns]

# %% [markdown]
# #### 🔄 Redundancies:
# Are columns like `fossil_fuel_consumption` and the sum of `coal_share_elec + gas_share_elec + oil_share_elec` consistent?

# %%
# 🔍 Sample of Selected Columns
df[['fossil_fuel_consumption', 'coal_share_elec', 'gas_share_elec', 'oil_share_elec']].sample(5)
# Out:
#        fossil_fuel_consumption  coal_share_elec  gas_share_elec  \
# 2325                   472.560              NaN             NaN
# 862                        NaN              NaN             NaN
# 774                        NaN              NaN             NaN
# 11276                   48.843              0.0          90.596
# 19496                      NaN              NaN             NaN
#
#        oil_share_elec
# 2325              NaN
# 862               NaN
# 774               NaN
# 11276           1.254
# 19496             NaN

# %% [markdown]
# #### 3️⃣ Data Cleaning & Transformation
#
# **Key Decisions:**
# - **Missing values strategy:** Impute, remove, or label as "Not available"?
#   - Depends on analytical impact (e.g., if 80% of `biofuel_electricity` is missing, consider excluding it).

# %%
# General Column information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16936 entries, 24 to 21811
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  16936 non-null  object
#  1   year                                     16936 non-null  int64
#  2   iso_code                                 16812 non-null  object
#  3   population                               16806 non-null  float64
#  4   gdp                                      11572 non-null  float64
#  5   biofuel_electricity                      5293 non-null   float64
#  6   carbon_intensity_elec                    5294 non-null   float64
#  7   coal_electricity                         5667 non-null   float64
#  8   coal_production                          13120 non-null  float64
#  9   coal_share_elec                          5644 non-null   float64
#  10  electricity_demand                       5322 non-null   float64
#  11  electricity_generation                   6213 non-null   float64
#  12  energy_cons_change_pct                   9678 non-null   float64
#  13  energy_cons_change_twh                   9830 non-null   float64
#  14  energy_per_gdp                           7737 non-null   float64
#  15  fossil_electricity                       5716 non-null   float64
#  16  fossil_energy_per_capita                 3688 non-null   float64
#  17  fossil_fuel_consumption                  3688 non-null   float64
#  18  gas_electricity                          5601 non-null   float64
#  19  gas_production                           13305 non-null  float64
#  20  gas_share_elec                           5578 non-null   float64
#  21  greenhouse_gas_emissions                 5322 non-null   float64
#  22  hydro_electricity                        7394 non-null   float64
#  23  low_carbon_electricity                   6593 non-null   float64
#  24  net_elec_imports                         5298 non-null   float64
#  25  net_elec_imports_share_demand            5270 non-null   float64
#  26  nuclear_electricity                      8110 non-null   float64
#  27  nuclear_share_elec                       6082 non-null   float64
#  28  oil_electricity                          5711 non-null   float64
#  29  oil_production                           13783 non-null  float64
#  30  oil_share_elec                           5688 non-null   float64
#  31  other_renewable_electricity              6841 non-null   float64
#  32  other_renewable_exc_biofuel_electricity  4729 non-null   float64
#  33  per_capita_electricity                   6213 non-null   float64
#  34  primary_energy_consumption               10049 non-null  float64
#  35  renewables_consumption                   4198 non-null   float64
#  36  renewables_electricity                   6593 non-null   float64
#  37  renewables_share_elec                    5974 non-null   float64
#  38  solar_electricity                        6642 non-null   float64
#  39  wind_electricity                         6671 non-null   float64
# dtypes: float64(37), int64(1), object(2)
# memory usage: 5.3+ MB

# %%
# 🚫 Null Values per Column
nulos = df.isna().sum()
nulos[nulos > 0]
# Out:
# iso_code                                     124
# population                                   130
# gdp                                         5364
# biofuel_electricity                        11643
# carbon_intensity_elec                      11642
# coal_electricity                           11269
# coal_production                             3816
# coal_share_elec                            11292
# electricity_demand                         11614
# electricity_generation                     10723
# energy_cons_change_pct                      7258
# energy_cons_change_twh                      7106
# energy_per_gdp                              9199
# fossil_electricity                         11220
# fossil_energy_per_capita                   13248
# fossil_fuel_consumption                    13248
# gas_electricity                            11335
# gas_production                              3631
# gas_share_elec                             11358
# greenhouse_gas_emissions                   11614
# hydro_electricity                           9542
# low_carbon_electricity                     10343
# net_elec_imports                           11638
# net_elec_imports_share_demand              11666
# nuclear_electricity                         8826
# nuclear_share_elec                         10854
# oil_electricity                            11225
# oil_production                              3153
# oil_share_elec                             11248
# other_renewable_electricity                10095
# other_renewable_exc_biofuel_electricity    12207
# per_capita_electricity                     10723
# primary_energy_consumption                  6887
# renewables_consumption                     12738
# renewables_electricity                     10343
# renewables_share_elec                      10962
# solar_electricity                          10294
# wind_electricity                           10265
# dtype: int64

# %%
# 📊 Plot Null Value Distribution

# Null values per column
null_values = df.isna().sum()

fig, ax = plt.subplots(figsize=(18,7))

higher_nulls = null_values[null_values > 200].sort_values(ascending=False)

# Plot columns with significant missing values
higher_nulls.plot(kind='bar', ax=ax, color='teal')

ax.set_title('Missing Values Count', fontsize=18, fontweight='bold')
ax.set_xticklabels(higher_nulls.index, rotation=45)
ax.set_xlabel('Columns', fontsize=16, fontweight='semibold')
ax.set_ylabel('Count', fontsize=16, fontweight='semibold')
ax.set_ylim(0, 13500)
ax.set_yticks(range(0, 13001, 1000))
ax.grid(linewidth=0.2)

plt.show()

# %%
# 📊 Null Values Summary per Column

# Count null values per column
null_values = df.isna().sum()

# Total number of rows
total_rows = df.shape[0]

# Convert total rows into a Series for concatenation
total_rows_series = pd.Series(total_rows, index=df.columns)

# Calculate percentage of missing values
null_percentage = round(null_values / total_rows * 100, 2)

# Create summary DataFrame
df_summary = pd.concat([null_values, total_rows_series, null_percentage], 
                        keys=['Null Count', 'Total Rows', '% Null'], axis=1)

df_summary
# Out:
#                                          nulos  total  % nulos
# country                                      0  16936     0.00
# year                                         0  16936     0.00
# iso_code                                   124  16936     0.73
# population                                 130  16936     0.77
# gdp                                       5364  16936    31.67
# biofuel_electricity                      11643  16936    68.75
# carbon_intensity_elec                    11642  16936    68.74
# coal_electricity                         11269  16936    66.54
# coal_production                           3816  16936    22.53
# coal_share_elec                          11292  16936    66.67
# electricity_demand                       11614  16936    68.58
# electricity_generation                   10723  16936    63.31
# energy_cons_change_pct                    7258  16936    42.86
# energy_cons_change_twh                    7106  16936    41.96
# energy_per_gdp                            9199  16936    54.32
# fossil_electricity                       11220  16936    66.25
# fossil_energy_per_capita                 13248  16936    78.22
# fossil_fuel_consumption                  13248  16936    78.22
# gas_electricity                          11335  16936    66.93
# gas_production                            3631  16936    21.44
# gas_share_elec                           11358  16936    67.06
# greenhouse_gas_emissions                 11614  16936    68.58
# hydro_electricity                         9542  16936    56.34
# low_carbon_electricity                   10343  16936    61.07
# net_elec_imports                         11638  16936    68.72
# net_elec_imports_share_demand            11666  16936    68.88
# nuclear_electricity                       8826  16936    52.11
# nuclear_share_elec                       10854  16936    64.09
# oil_electricity                          11225  16936    66.28
# oil_production                            3153  16936    18.62
# oil_share_elec                           11248  16936    66.41
# other_renewable_electricity              10095  16936    59.61
# other_renewable_exc_biofuel_electricity  12207  16936    72.08
# per_capita_electricity                   10723  16936    63.31
# primary_energy_consumption                6887  16936    40.66
# renewables_consumption                   12738  16936    75.21
# renewables_electricity                   10343  16936    61.07
# renewables_share_elec                    10962  16936    64.73
# solar_electricity                        10294  16936    60.78
# wind_electricity                         10265  16936    60.61

# %%
# 🚨 Columns with Excessive Missing Values (>70%)
incomplete_columns = df_summary[df_summary['% Null'] > 70]
incomplete_columns
# Out:
#                                          nulos  total  % nulos
# fossil_energy_per_capita                 13248  16936    78.22
# fossil_fuel_consumption                  13248  16936    78.22
# other_renewable_exc_biofuel_electricity  12207  16936    72.08
# renewables_consumption                   12738  16936    75.21

# %%
# 🗑️ Drop Columns with Excessive Missing Values (>70%)
df = df.drop(incomplete_columns.index, axis=1)
# Out:
#            country  year iso_code  population           gdp  coal_production  \
# 24     Afghanistan  1900      AFG   4707744.0           NaN            0.000
# 25     Afghanistan  1901      AFG   4751177.0           NaN            0.000
# 26     Afghanistan  1902      AFG   4802500.0           NaN            0.000
# 27     Afghanistan  1903      AFG   4861833.0           NaN            0.000
# 28     Afghanistan  1904      AFG   4921891.0           NaN            0.000
# ...            ...   ...      ...         ...           ...              ...
# 21807     Zimbabwe  2019      ZWE  15354606.0  2.514642e+10           19.700
# 21808     Zimbabwe  2020      ZWE  15669663.0  2.317871e+10           20.292
# 21809     Zimbabwe  2021      ZWE  15993525.0  2.514009e+10           24.291
# 21810     Zimbabwe  2022      ZWE  16320539.0  2.590159e+10           29.554
# 21811     Zimbabwe  2023      ZWE  16665407.0           NaN           37.413
#
#        energy_cons_change_pct  energy_cons_change_twh  gas_production  \
# 24                        NaN                     NaN             0.0
# 25                        NaN                     NaN             0.0
# 26                        NaN                     NaN             0.0
# 27                        NaN                     NaN             0.0
# 28                        NaN                     NaN             0.0
# ...                       ...                     ...             ...
# 21807                 -10.982                  -5.689             NaN
# 21808                  -8.940                  -4.123             NaN
# 21809                   0.354                   0.149             NaN
# 21810                     NaN                     NaN             NaN
# 21811                     NaN                     NaN             NaN
#
#        oil_production  primary_energy_consumption
# 24                NaN                         NaN
# 25                NaN                         NaN
# 26                NaN                         NaN
# 27                NaN                         NaN
# 28                NaN                         NaN
# ...               ...                         ...
# 21807             NaN                      46.120
# 21808             NaN                      41.997
# 21809             NaN                      42.145
# 21810             NaN                         NaN
# 21811             NaN                         NaN
#
# [16936 rows x 11 columns]

# %%
# 💾 Export DataFrame to CSV
df.to_csv('../data/owid-energy-data-filtered.csv', index=False)
